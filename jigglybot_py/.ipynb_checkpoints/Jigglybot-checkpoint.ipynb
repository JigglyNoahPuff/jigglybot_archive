# %%
# imports
import pandas as pd
import tensorflow.keras as keras
import os
import discord
import tensorflow as tf
from functions import *
# Out:
#   File "<ipython-input-6-d00df6e9fa96>", line 7
#     from functions import * as funs
#                             ^
# SyntaxError: invalid syntax

# %%
#Rythm: 235088799074484224
#Puff-Bot-2.0: 709247437189021740
#Freya813: 225802347115315202
#B̶l̶a̶c̶k̶j̶a̶c̶k̶ and Hookers: 221085790925488129
#Jigglemeserver: 498708057732153354

# %% [markdown]
# ![image.png](attachment:bb006a46-57c4-44c8-b489-1c7971274b4b.png)

# %%
#dat = pd.DataFrame({'name': ['Aero', 'Greengree', 'Freya813'], 'amount': [0, 0, 0]})
#dat = pd.read_csv('resin.csv')
dat.to_csv('resin.csv', index=False)
#resinVars = file.read()
print(dat.name.loc[0])
dat.head()
# Out:
# Aero
#         name  amount
# 0       Aero       0
# 1  Greengree       0
# 2   Freya813       0

# %%
dat = pd.read_csv('resin.csv')
i = list(dat.index[dat['name'] == 'Greengree'])[0]
#dat.iloc[i, dat.columns.get_loc('amount')] = 160
dat['amount'] = pd.Series([160,160,160])
dat['timeDone'] = pd.Series([0,0,0])
dat['notifs'] = pd.Series([False,True,False])
dat['resinNotif'] = pd.Series([160,160,160])
dat['fullNotif'] = pd.Series([False,False,False])
dat['userID'] = pd.Series([158761143945527296, 214238249152020480, 225802347115315202])
print(dat.amount[0])
dat.to_csv('resin.csv', index=False)
dat.head()
# Out:
# 160
#         name  amount  timeDone  notifs  resinNotif              userID  \
# 0       Aero     160         0   False         160  158761143945527296
# 1  Greengree     160         0    True         160  214238249152020480
# 2   Freya813     160         0   False         160  225802347115315202
#
#    fullNotif
# 0      False
# 1      False
# 2      False

# %%
i = list(dat.index[dat['name'] == 'Greengree'])[0]
dat.iloc[i, dat.columns.get_loc('amount')] = 149

# %%
dat = pd.read_csv('resin.csv')
if dat.notifs[2]:
    print('True')

# %%
print(dat.iloc[i])
# Out:
# name          Greengree
# amount              160
# timeDone              0
# notifs             True
# resinNotif            0
# Name: 1, dtype: object

# %%
def save():
    # Load in the data
    dat = pd.read_csv('resin.csv')
    # Data to be saved

    # Actually saving the data
    dat.to_csv('resin.csv', index=False)

# %%
list1 = ['genshin', 'resin', 40]
list2 = ['genshin', 'resin', 40, False]

print(len(list1))
print(len(list2))

yesDict = {0:['n', 'no', 'yah', 'ne', 'nope', 'false', 'False'],1:['y', 'yes', 'yah', 'ye', 'yep', 'yas', 'true', 'True']}

print('no' in yesDict[1])
# Out:
# 3
# 4
# False

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-5aabb966e927> in <module>
# ----> 1 int('一二三四五')
#
# ValueError: invalid literal for int() with base 10: '一二三四五'

# %%
x = 20015050
resinCap = lambda x: x if x <= 2000 else 2000
print(resinCap(x))

print(-x)
# Out:
# 2000
# -20015050

# %% [markdown]
# **Command:** genshin resin   <amount_current>   *optional_resinPartialAmount_numeric*    *optional_resinPartialNotif_boolean*  *optional_fullNotif_boolean*
